# %% [markdown]
# Lets Explore our Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('dataset/student.csv')

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.describe()
# Out:
#                age         Medu         Fedu   traveltime    studytime  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean     16.726054     2.603448     2.387931     1.522989     1.970307
# std       1.239975     1.124907     1.099938     0.731727     0.834353
# min      15.000000     0.000000     0.000000     1.000000     1.000000
# 25%      16.000000     2.000000     1.000000     1.000000     1.000000
# 50%      17.000000     3.000000     2.000000     1.000000     2.000000
# 75%      18.000000     4.000000     3.000000     2.000000     2.000000
# max      22.000000     4.000000     4.000000     4.000000     4.000000
#
#           failures       famrel     freetime        goout         Dalc  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      0.264368     3.935824     3.201149     3.156130     1.494253
# std       0.656142     0.933401     1.031507     1.152575     0.911714
# ...

# %%
df
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# Our Dataset contains 33 columns and 1044 rows

# %%
df.isna().any()
# Out:
# school                   False
# sex                      False
# age                      False
# address                  False
# family_size              False
# parents_status           False
# mother_education         False
# father_education         False
# mother_job               False
# father_job               False
# reason                   False
# guardian                 False
# commute_time             False
# study_time               False
# failures                 False
# school_support           False
# family_support           False
# paid_classes             False
# activities               False
# nursery                  False
# desire_higher_edu        False
# internet                 False
# romantic                 False
# family_quality           False
# free_time                False
# go_out                   False
# weekday_alcohol_usage    False
# weekend_alcohol_usage    False
# health                   False
# absences                 False
# ...

# %% [markdown]
# Thankfully, there is no missing value in the dataset.<br>
#
# G1 and G2 columns are useless and we only need the final score, so let's drop those for our ease.

# %%
df = df.drop(['G1','G2'], axis=1)

# %% [markdown]
# The names assigned to the columns are so vague and difficult to understand, let's give them better names.

# %%
# rename column labels
df.columns = ['school','sex','age','address','family_size','parents_status','mother_education','father_education',
           'mother_job','father_job','reason','guardian','commute_time','study_time','failures','school_support',
          'family_support','paid_classes','activities','nursery','desire_higher_edu','internet','romantic','family_quality',
          'free_time','go_out','weekday_alcohol_usage','weekend_alcohol_usage','health','absences','final_score']

# %%
df.head()
# Out:
#   school sex  age address family_size parents_status  mother_education  \
# 0     GP   F   18       U         GT3              A                 4
# 1     GP   F   17       U         GT3              T                 1
# 2     GP   F   15       U         LE3              T                 1
# 3     GP   F   15       U         GT3              T                 4
# 4     GP   F   16       U         GT3              T                 3
#
#    father_education mother_job father_job  ... internet romantic  \
# 0                 4    at_home    teacher  ...       no       no
# 1                 1    at_home      other  ...      yes       no
# 2                 1    at_home      other  ...      yes       no
# 3                 2     health   services  ...      yes      yes
# 4                 3      other      other  ...       no       no
#
#    family_quality  free_time  go_out weekday_alcohol_usage  \
# 0               4          3       4                     1
# ...

# %% [markdown]
# We will also be doing classification so we need to create anew column that contains Pass/Fail values.<br>
# Let's say whoever got 40% or 8/20 marks is pass and the rest have failed the exam

# %%
df['final_grade'] = 'na'
df.loc[(df.final_score >= 8) & (df.final_score <= 20), 'final_grade'] = 'pass' 
df.loc[(df.final_score < 8), 'final_grade'] = 'fail' 
df.head(5)
# Out:
#   school sex  age address family_size parents_status  mother_education  \
# 0     GP   F   18       U         GT3              A                 4
# 1     GP   F   17       U         GT3              T                 1
# 2     GP   F   15       U         LE3              T                 1
# 3     GP   F   15       U         GT3              T                 4
# 4     GP   F   16       U         GT3              T                 3
#
#    father_education mother_job father_job  ... romantic family_quality  \
# 0                 4    at_home    teacher  ...       no              4
# 1                 1    at_home      other  ...       no              5
# 2                 1    at_home      other  ...       no              4
# 3                 2     health   services  ...      yes              3
# 4                 3      other      other  ...       no              4
#
#    free_time  go_out  weekday_alcohol_usage weekend_alcohol_usage health  \
# ...

# %% [markdown]
# Let's see the distribution of the final scores of the students

# %%
# Visualize the distribution of the target variable (final_score)
plt.figure(figsize=(8, 6))
sns.histplot(df['final_score'], bins=20, kde=True)
plt.title('Distribution of Final Scores')
plt.xlabel('Final Score')
plt.ylabel('Frequency')
plt.show()

# %%
df.isnull().any()
# Out:
# school                   False
# sex                      False
# age                      False
# address                  False
# family_size              False
# parents_status           False
# mother_education         False
# father_education         False
# mother_job               False
# father_job               False
# reason                   False
# guardian                 False
# commute_time             False
# study_time               False
# failures                 False
# school_support           False
# family_support           False
# paid_classes             False
# activities               False
# nursery                  False
# desire_higher_edu        False
# internet                 False
# romantic                 False
# family_quality           False
# free_time                False
# go_out                   False
# weekday_alcohol_usage    False
# weekend_alcohol_usage    False
# health                   False
# absences                 False
# ...

# %% [markdown]
# Let's see the distribution of the PASS and FAIL students

# %%
# Final Grade Countplot
plt.figure(figsize=(8,6))
sns.countplot(x = df.final_grade, order=["pass","fail"], palette='Set1')
plt.title('Final Grade - Number of Students',fontsize=20)
plt.xlabel('Final Grade', fontsize=16)
plt.ylabel('Number of Student', fontsize=16)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_6544\2511276383.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = df.final_grade, order=["pass","fail"], palette='Set1')
# Text(0, 0.5, 'Number of Student')

# %% [markdown]
# Now, let's dive deep and explore the data.<br>
# Question - Does the romantic status of the students has anything to do with their exam scores?

# %%
# romantic status
perc = (lambda col: col/col.sum())
index = ['pass','fail']
romance_tab1 = pd.crosstab(index=df.final_grade, columns=df.romantic)
romance_tab = np.log(romance_tab1)
romance_perc = romance_tab.apply(perc).reindex(index)

plt.figure()
romance_perc.plot.bar(colormap="PiYG_r", fontsize=16, figsize=(8,8))
plt.title('Final Grade By Romantic Status', fontsize=20)
plt.ylabel('Percentage of Logarithm Student Counts ', fontsize=16)
plt.xlabel('Final Grade', fontsize=16)
plt.show()

# %% [markdown]
# We can see that there is not much difference between the frequency of passing and failing despite the relationship, so I don't think it effects that much.
#
# Question - Does Alcohol consumption on the weekend has anything to do with their scores?

# %%
# weekend alcohol consumption
alc_tab1 = pd.crosstab(index=df.final_grade, columns=df.weekend_alcohol_usage)
alc_tab = np.log(alc_tab1)
alc_perc = alc_tab.apply(perc).reindex(index)

# create good student dataframe
good = df.loc[df.final_grade == 'pass']
good['good_alcohol_usage']=good.weekend_alcohol_usage
# create poor student dataframe
poor = df.loc[df.final_grade == 'fail']
poor['poor_alcohol_usage']=poor.weekend_alcohol_usage

plt.figure(figsize=(10,6))
p1=sns.kdeplot(good['good_alcohol_usage'], shade=True, color="r")
p1=sns.kdeplot(poor['poor_alcohol_usage'], shade=True, color="b")
plt.title('Good Performance vs. Poor Performance Student Weekend Alcohol Consumption', fontsize=20)
plt.ylabel('Density', fontsize=16)
plt.xlabel('Level of Alcohol Consumption', fontsize=16)
plt.legend()
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_6544\1623517900.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good['good_alcohol_usage']=good.weekend_alcohol_usage
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_6544\1623517900.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poor['poor_alcohol_usage']=poor.weekend_alcohol_usage
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_6544\1623517900.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# ...

# %%
alc_perc.plot.bar(colormap="Reds", figsize=(10,8), fontsize=16)
plt.title('Final Grade By Weekend Alcohol Consumption', fontsize=20)
plt.ylabel('Percentage of Logarithm Student Counts', fontsize=16)
plt.xlabel('Final Grade', fontsize=16)
# Out:
# Text(0.5, 0, 'Final Grade')

# %% [markdown]
# We can see that the students with less consumption of Alcohol on the weekend have performed slightly better than their counterparts.<br>
#
# Question - Does the education level of the parents make a difference?

# %%
good['good_student_father_education'] = good.father_education
poor['poor_student_father_education'] = poor.father_education
good['good_student_mother_education'] = good.mother_education
poor['poor_student_mother_education'] = poor.mother_education

# see the difference between good and poor performers' father education level(numeric: from 1 - very low to 5 - very high)
plt.figure(figsize=(6,4))
p2=sns.kdeplot(good['good_student_father_education'], shade=True, color="r")
p2=sns.kdeplot(poor['poor_student_father_education'], shade=True, color="b")
plt.xlabel('Father Education Level', fontsize=20)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_6544\2061128380.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good['good_student_father_education'] = good.father_education
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_6544\2061128380.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poor['poor_student_father_education'] = poor.father_education
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_6544\2061128380.py:3: SettingWithCopyWarning:
# ...

# %%
# see the difference between good and poor performers' mother education level(numeric: from 1 - very low to 5 - very high)
plt.figure(figsize=(6,4))
p3=sns.kdeplot(good['good_student_mother_education'], shade=True, color="r")
p3=sns.kdeplot(poor['poor_student_mother_education'], shade=True, color="b")
plt.xlabel('Mother Education Level', fontsize=20)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_6544\1213818425.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   p3=sns.kdeplot(good['good_student_mother_education'], shade=True, color="r")
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_6544\1213818425.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   p3=sns.kdeplot(poor['poor_student_mother_education'], shade=True, color="b")
# Text(0.5, 0, 'Mother Education Level')

# %% [markdown]
# We can see that that a well educated mother has a very strong role in the final scores, father's education doesn't seem as important.
#
# Question - Does the frequency of how many times a student goes out every week effect their grades?

# %%
# going out with friends (numeric: from 1 - very low to 5 - very high)
plt.figure(figsize=(6,10))
sns.boxplot(x='go_out', y='final_score', data=df, palette='hot')
plt.title('Final Grade By Frequency of Going Out', fontsize=20)
plt.ylabel('Final Score', fontsize=16)
plt.xlabel('Frequency of Going Out', fontsize=16)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_6544\1418161285.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='go_out', y='final_score', data=df, palette='hot')
# Text(0.5, 0, 'Frequency of Going Out')

# %%
out_tab = pd.crosstab(index=df.final_grade, columns=df.go_out)
out_perc = out_tab.apply(perc).reindex(index)

out_perc.plot.bar(colormap="mako_r", fontsize=16, figsize=(14,6))
plt.title('Final Grade By Frequency of Going Out', fontsize=20)
plt.ylabel('Percentage of Student', fontsize=16)
plt.xlabel('Final Grade', fontsize=16)
# Out:
# Text(0.5, 0, 'Final Grade')

# %% [markdown]
# It can be seen that going out twice is good for you as it keeps you fresh and brings positive reults.
#
# Question - As students grow older, do they give more time to their studies depending upon if they want to pursue higher studeies?

# %%
# Desire for higher education and study time by age 
plt.figure(figsize=(12,8))
sns.violinplot(x='age', y='study_time', hue='desire_higher_edu', data=df, palette="Accent_r")
plt.title('Distribution Of Study Time By Age & Desire To Receive Higher Education', fontsize=20)
plt.ylabel('Study Time', fontsize=16)
plt.xlabel('Age', fontsize=16)
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# Question - Does the living area effect the performance of the students?

# %%
plt.figure(figsize=(6,6))
sns.countplot(x=df.address)
plt.title('Urban and Rural Students Count', fontsize=20)
plt.xlabel('Living Area', fontsize=16)
plt.ylabel('Number Of Students', fontsize=16)
plt.show()

# %%
ad_tab1 = pd.crosstab(index=df.final_grade, columns=df.address)
ad_tab = np.log(ad_tab1)
ad_perc = ad_tab.apply(perc).reindex(index)

ad_perc.plot.bar(colormap="RdYlGn_r", fontsize=16, figsize=(8,6))
plt.title('Final Grade By Living Area', fontsize=20)
plt.ylabel('Percentage of Logarithm Student#', fontsize=16)
plt.xlabel('Final Grade', fontsize=16)
# Out:
# Text(0.5, 0, 'Final Grade')

# %% [markdown]
# Not really, students performed equally, no matter where they belonged to.

# %% [markdown]
# Let's see the relationship of categorical variables with the final scores.

# %%
# Visualize relationships between categorical features and final_score

plt.figure(figsize=(16, 12))
categorical_features = ['school', 'sex', 'address', 'family_size', 'parents_status', 'mother_job', 'father_job', 'reason', 'guardian',
                         'school_support', 'family_support', 'paid_classes', 'activities', 'nursery', 'desire_higher_edu', 'internet', 'romantic']

for i, feature in enumerate(categorical_features, 1):
    plt.subplot(5, 4, i)
    sns.boxplot(x=feature, y='final_score', data=df)
    plt.title(f'{feature} vs. final_Score')

plt.tight_layout()
plt.show()

# %% [markdown]
# It can be seen that, the students who joined their schools on reputation, or those whose parents were teachers or healthworkers perfrormed better than others.

# %%
# Visualize relationships between numerical features and G3
plt.figure(figsize=(16, 12))
numerical_features = ['age', 'mother_education', 'father_education', 'commute_time', 'study_time', 'failures', 'family_quality', 'free_time',
                      'go_out', 'weekday_alcohol_usage', 'weekend_alcohol_usage', 'health', 'absences']

for i, feature in enumerate(numerical_features, 1):
    plt.subplot(4, 4, i)
    sns.scatterplot(x=feature, y='final_score', data=df)
    plt.title(f'{feature} vs. final_Score')

plt.tight_layout()
plt.show()

# %%
# Assuming 'df' is your original DataFrame with categorical columns
df_encoded = pd.get_dummies(df, columns=['school', 'sex', 'address', 'family_size', 'parents_status', 'mother_job', 'father_job',
                                         'reason', 'guardian', 'school_support', 'family_support', 'paid_classes', 'activities',
                                         'nursery', 'desire_higher_edu', 'internet', 'romantic'], drop_first=True)

# Convert any remaining non-numeric columns to numeric (assuming these are ordinal values)
# Convert any remaining non-numeric columns to numeric (assuming these are ordinal values)
df_encoded = df_encoded.apply(pd.to_numeric, errors='coerce')

# Check for any non-numeric columns
non_numeric_columns = df_encoded.select_dtypes(exclude=['number']).columns
if not non_numeric_columns.empty:
    print(f"Warning: Non-numeric columns present: {non_numeric_columns}")

# 6. Correlations
print("\n6. Correlations:")
correlation_matrix = df_encoded.corr()
plt.figure(figsize=(25, 20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# ...
#        'parents_status_T', 'mother_job_health', 'mother_job_other',
#        'mother_job_services', 'mother_job_teacher', 'father_job_health',
#        'father_job_other', 'father_job_services', 'father_job_teacher',
#        'reason_home', 'reason_other', 'reason_reputation', 'guardian_mother',
#        'guardian_other', 'school_support_yes', 'family_support_yes',
#        'paid_classes_yes', 'activities_yes', 'nursery_yes',
#        'desire_higher_edu_yes', 'internet_yes', 'romantic_yes'],
#       dtype='object')
#
# 6. Correlations:
